# %% [markdown]
# <h1> Libreta de Resultados </h1>
# <h3> Trabajo realizado por: </h3>
# <p> Pol Fonoyet González </p>
# <p>Yassin El Kaisi Rahmoun </p>
# <p>Gorka Parra Ordorica </p>
# <p>Tahir Muhammad Aziz </p>

# %% [markdown]
# <h2> Importación de librerias </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2> Recopilación de datos </h2>
#
# <p> Estos datos se han generado con el "main automático". </p>
# <p> El código de este se encuentra en el apéndice del informe </p>

# %%
col_names = ["k=2","k=3","k=4","k=5","k=6"]

dades_est5k = [
[25,45,87,168,307],
[27,49,97,191,368],
[28,51,101,206,406],
[29,52,106,216,429],
[29,53,108,222,449],
[29,54,112,229,470],
[30,55,113,238,483],
[30,56,116,244,501],
[31,57,117,244,513],
[31,57,119,249,525],
[31,57,118,252,527],
[31,58,122,257,540],
[32,59,121,259,547],
[32,59,123,262,550],
[32,60,123,265,556],
[32,60,124,266,565],
[32,60,124,273,569],
[32,60,126,273,573],
[33,61,126,273,578],
[33,60,126,274,588]]

dades_rel5k = [
[28,55,108,206,365],
[31,61,124,250,459],
[32,64,135,271,515],
[33,67,140,289,558],
[34,70,146,308,589],
[34,70,153,313,629],
[35,73,156,322,655],
[35,73,160,330,680],
[36,75,161,341,696],
[36,76,167,350,704],
[37,77,167,356,730],
[37,78,167,357,733],
[37,79,175,368,763],
[38,81,170,374,775],
[38,80,174,375,784],
[38,78,177,383,794],
[38,81,180,383,798],
[39,82,180,389,812],
[39,83,183,393,830],
[39,82,183,409,838]]

dades_squ5k = [
[23,38,71,136,254],
[24,41,77,150,295],
[25,42,80,160,318],
[26,43,82,165,333],
[26,44,83,168,347],
[26,44,85,172,355],
[27,44,86,177,362],
[27,45,87,178,372],
[27,45,88,181,378],
[27,46,88,182,380],
[28,46,89,184,386],
[28,46,90,186,393],
[28,47,90,188,393],
[28,47,91,189,401],
[28,47,91,191,403],
[29,47,92,192,407],
[29,47,92,192,408],
[29,48,92,193,411],
[29,47,92,194,412],
[29,48,93,194,416]]

filas = np.arange(5000,105000,5000)

# %% [markdown]
# <h2> Creación de las tablas con Pandas </h2>

# %%
df_est5k = pd.DataFrame(dades_est5k, columns = col_names)
df_rel5k = pd.DataFrame(dades_rel5k, columns = col_names)
df_squ5k = pd.DataFrame(dades_squ5k, columns = col_names)

# %% [markdown]
# <h2> Generación de las gráficas </h2>

# %%
fig = plt.figure(figsize=(4,2),dpi=200)

axes = fig.add_axes([0,0,1,1])
axes.plot(filas, df_est5k["k=2"],label="k=2")
axes.plot(filas, df_est5k["k=3"],label="k=3")
axes.plot(filas, df_est5k["k=4"],label="k=4")
axes.plot(filas, df_est5k["k=5"],label="k=5")
axes.plot(filas, df_est5k["k=6"],label="k=6")

axes.tick_params(axis='both', labelsize=4)

plt.title("k-d Standard Binary-Tree")

plt.xlabel("# nodos del árbol",fontsize=6)
plt.ylabel("# nodos consultados en la búsqueda", fontsize=6)
plt.legend(fontsize=6)

plt.show()

# %%
fig = plt.figure(figsize=(4,2),dpi=200)

axes = fig.add_axes([0,0,1,1])
axes.plot(filas, df_rel5k["k=2"],label="k=2")
axes.plot(filas, df_rel5k["k=3"],label="k=3")
axes.plot(filas, df_rel5k["k=4"],label="k=4")
axes.plot(filas, df_rel5k["k=5"],label="k=5")
axes.plot(filas, df_rel5k["k=6"],label="k=6")

axes.tick_params(axis='both', labelsize=4)

plt.title("k-d Relaxed Binary-Tree")

plt.xlabel("# nodos del árbol",fontsize=6)
plt.ylabel("# nodos consultados en la búsqueda", fontsize=6)
plt.legend(fontsize=6)

plt.show()

# %%
fig = plt.figure(figsize=(4,2),dpi=200)

axes = fig.add_axes([0,0,1,1])
axes.plot(filas, df_squ5k["k=2"],label="k=2")
axes.plot(filas, df_squ5k["k=3"],label="k=3")
axes.plot(filas, df_squ5k["k=4"],label="k=4")
axes.plot(filas, df_squ5k["k=5"],label="k=5")
axes.plot(filas, df_squ5k["k=6"],label="k=6")

axes.tick_params(axis='both', labelsize=4)

plt.title("k-d Squarish Binary-Tree")

plt.xlabel("# nodos del árbol",fontsize=6)
plt.ylabel("# nodos consultados en la búsqueda", fontsize=6)
plt.legend(fontsize=6)

plt.show()

# %% [markdown]
# <h2> Generación de las gráficas logarítmicas </h2>

# %%
fig = plt.figure(figsize=(4,2),dpi=200)

axes = fig.add_axes([0,0,1,1])
axes.plot(filas, df_est5k["k=2"],label="k=2")
axes.plot(filas, df_est5k["k=3"],label="k=3")
axes.plot(filas, df_est5k["k=4"],label="k=4")
axes.plot(filas, df_est5k["k=5"],label="k=5")
axes.plot(filas, df_est5k["k=6"],label="k=6")

axes.tick_params(axis='both', labelsize=4)

plt.title("k-d Standard Binary-Tree in log scale")

plt.xlabel("log(# nodos del arbol)",fontsize=6)
plt.ylabel("log(# nodos consultados en la búsqueda)", fontsize=6)
plt.legend(fontsize=6)

plt.yscale('log',base=2)
plt.xscale('log',base=2)

plt.show()

# %%
fig = plt.figure(figsize=(4,2),dpi=200)

axes = fig.add_axes([0,0,1,1])
axes.plot(filas, df_rel5k["k=2"],label="k=2")
axes.plot(filas, df_rel5k["k=3"],label="k=3")
axes.plot(filas, df_rel5k["k=4"],label="k=4")
axes.plot(filas, df_rel5k["k=5"],label="k=5")
axes.plot(filas, df_rel5k["k=6"],label="k=6")

axes.tick_params(axis='both', labelsize=4)

plt.title("k-d Relaxed Binary-Tree in log scale")

plt.xlabel("log(# nodos del arbol)",fontsize=6)
plt.ylabel("log(# nodos consultados en la búsqueda)", fontsize=6)
plt.legend(fontsize=6)

plt.yscale('log',base=2)
plt.xscale('log',base=2)

plt.show()

# %%
fig = plt.figure(figsize=(4,2),dpi=200)

axes = fig.add_axes([0,0,1,1])
axes.plot(filas, df_squ5k["k=2"],label="k=2")
axes.plot(filas, df_squ5k["k=3"],label="k=3")
axes.plot(filas, df_squ5k["k=4"],label="k=4")
axes.plot(filas, df_squ5k["k=5"],label="k=5")
axes.plot(filas, df_squ5k["k=6"],label="k=6")

axes.tick_params(axis='both', labelsize=4)

plt.title("k-d Squarish Binary-Tree in log scale")

plt.xlabel("log(# nodos del arbol)",fontsize=6)
plt.ylabel("log(# nodos consultados en la búsqueda)", fontsize=6)
plt.legend(fontsize=6)

plt.yscale('log',base=2)
plt.xscale('log',base=2)

plt.show()

# %% [markdown]
# <h2> Regression Lineal </h2>

# %%
from scipy.stats import linregress

# %%
for label in ["k=2", "k=3", "k=4", "k=5", "k=6"]:
    x = np.log2(n)
    y = np.log2(df_est5k[label])
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    print(f"Linear Regression for {label}: Slope = {slope}")
# Out:
# Linear Regression for k=2: Slope = 0.08694459326119805
# Linear Regression for k=3: Slope = 0.09870680452121647
# Linear Regression for k=4: Slope = 0.12208965183068363
# Linear Regression for k=5: Slope = 0.16226489286315096
# Linear Regression for k=6: Slope = 0.2088545156995361

# %%
for label in ["k=2", "k=3", "k=4", "k=5", "k=6"]:
    x = np.log2(n)
    y = np.log2(df_rel5k[label])
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    print(f"Linear Regression for {label}: Slope = {slope}")
# Out:
# Linear Regression for k=2: Slope = 0.10715701769641053
# Linear Regression for k=3: Slope = 0.13512456317440502
# Linear Regression for k=4: Slope = 0.1720642333275752
# Linear Regression for k=5: Slope = 0.212364517571227
# Linear Regression for k=6: Slope = 0.26859429202294793

# %%
for label in ["k=2", "k=3", "k=4", "k=5", "k=6"]:
    x = np.log2(n)
    y = np.log2(df_squ5k[label])
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    print(f"Linear Regression for {label}: Slope = {slope}")
# Out:
# Linear Regression for k=2: Slope = 0.07969461541134505
# Linear Regression for k=3: Slope = 0.07211468161786579
# Linear Regression for k=4: Slope = 0.0859007466792937
# Linear Regression for k=5: Slope = 0.11638471906121982
# Linear Regression for k=6: Slope = 0.15663074439497815
